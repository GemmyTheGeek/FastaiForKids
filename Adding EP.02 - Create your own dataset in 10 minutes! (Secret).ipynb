# %% [markdown]
# https://joedockrill.github.io/jmd_imagescraper/

# %%
# !pip install jmd_imagescraper

# %% [markdown]
# Importing the main classes

# %%
from jmd_imagescraper.core import * # dont't worry, it's designed to work with import *
from pathlib import Path

# %% [markdown]
# Set root = /system path + /current working directory + /images

# %%
root = Path().cwd()/"images"

# %% [markdown]
# Scrape images from duckduckgo
#
#
# *   Cats = destination directory
# *   cute kittens = keywords to search

# %%
duckduckgo_search(root, "Cats", "cute kittens", max_results=20)
# Out:
# Duckduckgo search: cute kittens
# ...
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='20' class='' max='20' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [20/20 00:01<00:00 Images downloaded]
#     </div>
# [PosixPath('/content/images/Cats/001_fd9377cb.jpg'),
#  PosixPath('/content/images/Cats/002_95395947.jpg'),
#  PosixPath('/content/images/Cats/003_05454f78.jpg'),
#  PosixPath('/content/images/Cats/004_49629098.jpg'),
# ...

# %% [markdown]
# Clean images

# %%
from jmd_imagescraper.imagecleaner import *

# %%
display_image_cleaner(root)
# Out:
# ...
# HTML(value='<h2>No images left to display in this folder.</h2>', layout=Layout(visibility='hidden'))
# GridBox(children=(VBox(children=(Image(value=b'', layout="Layout(width='150px')"), Button(description='Delete'…

# %% [markdown]
# Compress all images to single zip file

# %%
# !zip -r /content/ImagesfromColab.zip /content/images
# Out:
#   adding: content/images/ (stored 0%)
#   adding: content/images/Cats/ (stored 0%)
#   adding: content/images/Cats/018_e5bcee85.jpg (deflated 1%)
#   adding: content/images/Cats/019_79f13b24.jpg (deflated 0%)
#   adding: content/images/Cats/002_bd133f41.jpg (deflated 1%)
#   adding: content/images/Cats/010_4eef4d9f.jpg (deflated 1%)
#   adding: content/images/Cats/015_fddec604.jpg (deflated 1%)
#   adding: content/images/Cats/004_c28f0096.jpg (deflated 1%)
#   adding: content/images/Cats/012_2c9078f1.jpg (deflated 1%)
#   adding: content/images/Cats/016_b5585aca.jpg (deflated 3%)
#   adding: content/images/Cats/005_0011504d.jpg (deflated 1%)
#   adding: content/images/Cats/017_e2dbf125.jpg (deflated 0%)
#   adding: content/images/Cats/007_22bfeb62.jpg (deflated 1%)
#   adding: content/images/Cats/011_d5ed819a.jpg (deflated 1%)
#   adding: content/images/Cats/013_2ba2818f.jpg (deflated 1%)
#   adding: content/images/Cats/003_6a351f62.jpg (deflated 1%)
# ...

# %% [markdown]
# You can download zip file to your computer

# %% [markdown]
# ##Homework
# think about your own image classification project
